# %%
from agent_heatmap import create_sentiment_heatmap
import pandas as pd

# %%
for i in range(0,12):
    df = pd.read_csv('KData/eval_metric_100_' + str(i) + '.csv')
    path='Viz/Heatmap_conv100_'+str(i)
    create_sentiment_heatmap(df,"Agent1",path+"_Agent1.png")
    create_sentiment_heatmap(df,"Agent2",path+"_Agent2.png")
